# %% [markdown]
# ### 추출을 위한 라이브러 및 파일 임포트

# %%
import pandas as pd

# %%
df = pd.read_csv('소상공인시장진흥공단_상가업소정보_201906_01.csv',engine='python',encoding='UTF-8')

# %% [markdown]
# #### 사용할 컬럼을 고르기 위해 컬럼이름 확인

# %%
df.columns.values
# Out:
# array(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명',
#        '건물본번지', '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호',
#        '동정보', '층정보', '호정보', '경도', '위도'], dtype=object)

# %% [markdown]
# #### 강남 시군구 코드(11680)과 매칭되는 데이터 추출

# %%
gangnam = df[df['시군구코드'] == 11680]

# %%
gangnam
# Out:
#           상가업소번호             상호명         지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드  \
# 0       19911397   커피빈코리아선릉로93길점  코리아선릉로93길점         Q        음식       Q12
# 3       19905471          와라와라호프         NaN         Q        음식       Q09
# 26      20014818              쉼터         NaN         Q        음식       Q04
# 27      20015136  배제현의웰빙낙지한마리수제비         NaN         Q        음식       Q03
# 38      20024149        타워광명내과의원         NaN         S        의료       S01
# 39      20027817            마깐바냑         NaN         Q        음식       Q04
# 40      20027870            강남김밥         NaN         Q        음식       Q04
# 46      20099319           산울FNC         NaN         Q        음식       Q04
# 65      20482406         소노야코엑스점        코엑스점         Q        음식       Q03
# 71      20808534          코원성형외과         NaN         S        의료       S01
# 84      20727381          한일지도판매         NaN         D        소매       D13
# ...

# %% [markdown]
# #### 파일 엑스포트

# %%
gangnam.to_csv('소상공인(강남).csv',encoding='utf-8')
